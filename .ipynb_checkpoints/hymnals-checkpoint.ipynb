# %%
import pandas as pd
from pandas import DataFrame, Series
from bs4 import BeautifulSoup as soup
from pprint import pprint
import os, sys

# %%
# %cd data/denson-xml
# Out:
# /home/gideon/Scratch/hymnals/data/denson-xml

# %%
def find_tenor_id(asoup):
    '''
    Returns the id of the tenor part in an xml soup.
    '''
    parts = asoup.findAll('score-part')
    for part in parts:
        if part.find('part-name').text.lower() == 'tenor':
            return part['id']
    else:
        return None

def pitch_for_note(note, fp):
    '''
    Xml note node, (opened) file -> string (the note).
    '''
    try:
        return note.pitch.step.text
    except:
        try:
            return note.step.text
        except:
            if note.rest:
                return 'rest'
            else:
                raise Exception("note {} that's neither rest nor pitch in {}".format(note, fp))

def rhythm_for_note(note):
    if note.rest:
        return note.type.text
    else:
        return 

def type_for_note(note, fp):
    '''
    Returns either the type (quarter, half, etc) or rest.
    '''
    if note.find('rest'):
        dur = note.type or note.duration
        return dur.text
    else:
        return note.type.text

def frame_from_file(filepath):
    '''
    The meaty data munger.
    
    path/to/file -> DataFrame.
    
    The DataFrame, subject to change, looks something like this:
    
    pitch | rhythm | measure_no | note_no | title | key_fifths | key_mode | time_beats | time_beat_type.
    
    Basically, each row is a note in a song.
    '''
    asoup = soup(open(filepath).read(), 'xml')
    tenor_id = find_tenor_id(asoup)
    if not tenor_id:
        print filepath + " has no tenor part. Ignoring this file."
        return
    tenor_part = asoup.select('part#' + tenor_id)
    
    if not tenor_part:
        print "NO TENOR PART FOR", tenor_id, "IN", filepath
        return None

    try:
        notes = []
        measures = tenor_part[0].findAll('measure')
        for measure_idx, measure in enumerate(measures):
            for note_idx, note in enumerate(measure.findAll('note')):
                pitch = pitch_for_note(note, filepath)
                _type = type_for_note(note, filepath)
                dotted = note.dot is not None
                notes.append((pitch, _type, measure_idx, note_idx, dotted))
        dat = DataFrame(notes, columns=("pitch", "rhythm", "measure_no", "note_no", "is_dotted"))
        
        title_el = asoup.find('movement-title') or asoup.work.find('work-title')
        title = title_el.text
        if not title:
            print filename + " has no title?!"
            return
        dat['title'] = title
        
        attrs = asoup.find('part').find('measure').attributes  
        key = attrs.key
        
        if not key:
            print "Assuming that <" + filename + "> is in the key of C major."
            dat['key_fifths'] = 0
            dat['key_mode'] = 'major'
        else:
            dat['key_fifths'] = attrs.key.fifths.text
            try:
                dat['key_mode'] = attrs.key.mode.text
            except:
                dat['key_mode'] = 'minor'
            dat['time_beats'] = attrs.time.beats.text
            dat['time_beat_type'] = attrs.time.find('beat-type').text
            return dat
    except Exception as e:
        raise Exception('Problem <{}> with file: {}'.format(e, filename))

# %%
# use tenor extractor on each soup
# get all the soups with tenor parts
# grab all the tenor parts
# append each part to the dataframe
file_list = [afile for afile in os.listdir(os.getcwd()) if 'xml' in afile]

file_list = file_list[:100]

dats = [frame_from_file(filename) for filename in file_list]
songbag = pd.concat(dats)

# %%
def compute_dotted_rhythm((rhy, isdotted)):
    '''
    int, bool -> int.
    Helper function, see below.
    '''
    if isdotted:
        return rhy + rhy*.5
    else:
        return rhy

note_to_time = {u'quarter': 1, u'half': 2, u'whole': 4, u'eighth': 1.0/2, u'16th': 1.0/4, u'sixteenth': 1.0/4}
four_four = songbag[songbag['time_beat_type'] == '4']
four_four = four_four[four_four['time_beats'] == '4']

# for each measure in each song, determine which
# notes are emphasized and put them into an array emphs.
# Later, this emphs will be added as a column of the data matrix.
emphs = []
titles = four_four.title.unique()
for title in titles:
    df = four_four[four_four.title == title]
    for _, measure in df.groupby(df.measure_no):
        beats = [note_to_time[x] for x in measure.rhythm]
        beats = map(compute_dotted_rhythm, zip(beats, measure.is_dotted))
        
        acc = 0
        for count in beats:
            is_emphasized = False
            if 0 == acc or 2 == acc:
                # only grab notes which are on the first and third beats.
                is_emphasized = True
            emphs.append(is_emphasized)
            acc+=count

emphs = Series(emphs)
four_four['is_emphasized'] = emphs
emphasized = four_four[four_four.is_emphasized]
emphasized = emphasized[emphasized.rhythm != 'rest']

# %%
# Best to think about the motif creating process.
# It is simply choosing a window length, and tracking that window length across the song.
# If you choose motif_length == 2 then you get all intervals between notes (rests are ignored).
# This is exactly what bioinformaticians do with k-mers.

notes = ["A","B","C","D","E","F","G"]
note_to_degree = dict([(v,i) for i,v in enumerate(notes)])
motif_length = 2

motifs = []
for title in emphasized.title.unique():
    song = emphasized[emphasized.title == title]
    song = song[song.pitch != "rest"]
    key_fifth = int(list(song.key_fifths[:1])[0])      # this sucks, how to get an element of a Series?
    for i in xrange(len(song.pitch)-1):
        # grab the next motif
        motif = song.pitch[i:i+motif_length]
        # transpose to the key of C, just leave as degrees of a scale
        motif = [(note_to_degree[p]-key_fifth) % len(notes) for p in motif]
        
        motifs.append((title,motif))
    
motifs = DataFrame(motifs, columns=["title", "motif"])

# %%
from itertools import permutations
motif_to_index = dict([(v,i) for i,v in enumerate([x for x in permutations(range(len(notes)), motif_length)] + [tuple([x] * motif_length) for x in range(len(notes))])])

# %%
from math import sqrt
def distance(featurex,featurey):
    '''Nuttin but Euclid.'''
    return abs(sqrt(sum([i * i for i in featurex])) - sqrt(sum([i * i for i in featurey])))

# %%
SongsInFeatureSpace
# Out:
#                                        title  \
# 0                              NEWBURGH, 182
# 1                        JORDAN (Second),439
# 2                 ODE ON LIFE'S JOURNEY, 227
# 3                      ALL SAINTS NEW, 444
# 4                               ECSTASY, 106
# 5                         HEAVENLY HOME, 286
# 6                               AINSLIE, 348
# 7                               PHOEBUS, 173
# 8                    PROTECTION (First), 187
# 9                         DAY OF WORSHIP, 60
# 10                              KELLEY, 426t
# 11                           PRAISE HIM, 544
# 12                          AS WE GO ON, 488
# 13                                LOGAN, 302
# 14                          EXHORTATION, 272
# 15                           ADORATION, 138t
# 16                             DEVOTION, 48t
# 17                  CHRISTIAN'S DELIGHT, 429
# 18  WHERE THERE'S NO TROUBLE AND SORROW, 465
# 19                     CROSS OF CHRIST, 123b
# ...
